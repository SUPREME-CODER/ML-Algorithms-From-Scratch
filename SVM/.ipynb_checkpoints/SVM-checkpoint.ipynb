# %% [markdown]
# ## Loading the libraries

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.preprocessing import MinMaxScaler

# %%
def load_data():
    data = pd.read_csv("data.csv")
    data.replace({'diagnosis':{'M':1.0, 'B':-1.0}}, inplace=True)
    data.drop(['id', 'Unnamed: 32'], axis=1, inplace=True)
    return data

# %%
pd.set_option('display.max_columns', None)

# %%
data = load_data()
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0        1.0        17.99         10.38          122.80     1001.0
# 1        1.0        20.57         17.77          132.90     1326.0
# 2        1.0        19.69         21.25          130.00     1203.0
# 3        1.0        11.42         20.38           77.58      386.1
# 4        1.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# 0         0.2419                 0.07871     1.0950      0.9053         8.589
# 1         0.1812                 0.05667     0.5435      0.7339         3.398
# 2         0.2069                 0.05999     0.7456      0.7869         4.585
# 3         0.2597                 0.09744     0.4956      1.1560         3.445
# 4         0.1809                 0.05883     0.7572      0.7813         5.438
#
#    area_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0   153.40       0.006399         0.04904       0.05373            0.01587
# 1    74.08       0.005225         0.01308       0.01860            0.01340
# 2    94.03       0.006150         0.04006       0.03832            0.02058
# 3    27.23       0.009110         0.07458       0.05661            0.01867
# 4    94.44       0.011490         0.02461       0.05688            0.01885
#
#    symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 0      0.03003              0.006193         25.38          17.33
# 1      0.01389              0.003532         24.99          23.41
# 2      0.02250              0.004571         23.57          25.53
# 3      0.05963              0.009208         14.91          26.50
# 4      0.01756              0.005115         22.54          16.67
#
#    perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           184.60      2019.0            0.1622             0.6656
# 1           158.80      1956.0            0.1238             0.1866
# 2           152.50      1709.0            0.1444             0.4245
# 3            98.87       567.7            0.2098             0.8663
# 4           152.20      1575.0            0.1374             0.2050
#
#    concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.7119                0.2654          0.4601
# 1           0.2416                0.1860          0.2750
# 2           0.4504                0.2430          0.3613
# 3           0.6869                0.2575          0.6638
# 4           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst
# 0                  0.11890
# 1                  0.08902
# 2                  0.08758
# 3                  0.17300
# 4                  0.07678

# %% [markdown]
# ## Normalization and Processing

# %%
def min_max_normalization(data):
    numcols = data.shape[1]
    for col in data.columns:
        data[col] = ((data[col] - np.min(data[col]))/(np.max(data[col]) - np.min(data[col])))

# %%
Y = data['diagnosis']
X = data.drop('diagnosis', axis=1)
min_max_normalization(X)
X = X.assign(bias=1)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 68      0.096928      0.257694        0.103656   0.045387         0.487226
# 181     0.667755      0.570172        0.683505   0.495228         0.554934
# 63      0.103744      0.140345        0.106489   0.049799         0.221901
# 248     0.173648      0.524518        0.167369   0.086320         0.396678
# 60      0.150930      0.174839        0.143459   0.071432         0.548614
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 68           0.373965        0.733365             0.217445       0.530808
# 181          0.809214        0.582709             0.743539       0.674242
# 63           0.208975        0.140300             0.108350       0.646970
# 248          0.162444        0.055740             0.080268       0.422727
# 60           0.187811        0.025398             0.064115       0.850000
#
#      fractal_dimension_mean  radius_se  texture_se  perimeter_se   area_se  \
# 68                 0.642376   0.078182    0.184273      0.053150  0.020299
# 181                0.505897   0.187688    0.088998      0.172313  0.139444
# 63                 0.414280   0.108021    0.420969      0.087217  0.031225
# 248                0.280750   0.050045    0.250354      0.034868  0.018375
# 60                 0.413648   0.146406    0.238861      0.120388  0.051958
#
#      smoothness_se  compactness_se  concavity_se  concave points_se  \
# 68        0.266377        0.629435      0.767172           0.629286
# 181       0.086345        0.340508      0.097778           0.296837
# 63        0.238807        0.278848      0.108889           0.295511
# 248       0.186151        0.060820      0.027298           0.118299
# 60        0.197199        0.065626      0.019356           0.155200
#
#      symmetry_se  fractal_dimension_se  radius_worst  texture_worst  \
# 68      0.479653              0.299331      0.084667       0.283316
# 181     0.142089              0.152018      0.667022       0.571962
# 63      0.478950              0.170225      0.073995       0.192164
# 248     0.192745              0.059568      0.153682       0.617537
# 60      0.477683              0.174751      0.109925       0.144723
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 68          0.075153    0.034285          0.508684           0.397018
# 181         0.627970    0.467902          0.514627           0.709327
# 63          0.075601    0.030697          0.179555           0.136324
# 248         0.137308    0.066482          0.519910           0.109158
# 60          0.096867    0.045075          0.371987           0.069244
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 68          1.000000              0.601375        0.524936
# 181         0.541534              0.997595        0.499310
# 63          0.111581              0.174811        0.338459
# 248         0.089856              0.210859        0.363493
# 60          0.017316              0.088625        0.392667
#
#      fractal_dimension_worst  bias
# 68                  0.409681     1
# 181                 0.481175     1
# 63                  0.195855     1
# 248                 0.173357     1
# 60                  0.165027     1

# %%
Y_train.head()
# Out:
# 68    -1.0
# 181    1.0
# 63    -1.0
# 248   -1.0
# 60    -1.0
# Name: diagnosis, dtype: float64

# %% [markdown]
# ## SVM
# $\large{f(x) = sign(w^*.x + b^*)}$

# %% [markdown]
# ## Cost
# $\large{J(w) = \frac{1}{2}}||w||^2 + C[\frac{1}{N}\sum_{i=1}^{n}max(0, 1-y_{i}*(w.x_{i} + b))]$<br><br>
# $OR$<br><br>
# $\large{J(w) = \frac{\lambda}{2}}||w||^2 + \frac{1}{N}\sum_{i=1}^{n}max(0, 1-y_{i}*(w.x_{i} + b))$

# %%
def calculate_cost(W, X, Y):
    numRows = X.shape[0]
    margins = 1 - Y * (np.dot(X, W))
    margins[margins < 0] = 0
    hingeLoss = C * (np.sum(margins) / numRows)
    cost = (1 / 2) * np.dot(W, W) + hingeLoss
    return cost

# %% [markdown]
# ## The Cost Gradient
#
# $\large{\frac{\partial J(w)}{\partial w}} = \frac{1}{N}\sum_{i=1}^{N}w\hspace{35mm} \text{if max}(0, 1 - y_{i}*(w.x_{i})) = 0$<br><br>
#
#
# $\large{\frac{\partial J(w)}{\partial w}} = \frac{1}{N}\sum_{i=1}^{N}w - Cy_{i}x_{i}\hspace{13mm} \text{otherwise}$

# %%
def calculate_cost_gradient(W, X_point, Y_point):
    if type(Y_point) == np.float64:
        Y_point = np.array([Y_point])
        X_point = np.array([X_point])
    
    margins = 1 - (Y_point * np.dot(X_point, W))
    dw = np.zeros(len(W))

    for i, d in enumerate(margins):
        dw += W if d < 0 else  W - (C * Y_point[i] * X_point[i])
    dw = dw/len(Y_point)
    return dw

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(X_train, Y_train, max_epochs = 5000):
    W = np.zeros(X_train.shape[1])
    for epoch in range(1, max_epochs+1):
        grad = calculate_cost_gradient(W, X_train, Y_train)
        W = W - (learningRate * grad)
        
        if epoch in (1, 10, 100) or epoch % 1000 == 0:
            print('Epoch - ', epoch, ' Cost - ', calculate_cost(W, X_train, Y_train))
            
    return W

# %%
C = 10000
learningRate = 0.000001
W = gradient_descent(X_train.to_numpy(), Y_train.to_numpy(), 15000)
print("\nWeights: {}".format(W))
# Out:
# Epoch -  1  Cost -  9987.81504503144
# Epoch -  10  Cost -  9878.151546953944
# Epoch -  100  Cost -  8781.62512625697
# Epoch -  1000  Cost -  3170.8983416563465
# Epoch -  2000  Cost -  2314.0535365699025
# Epoch -  3000  Cost -  1999.9975721499009
# Epoch -  4000  Cost -  1836.786188209553
# Epoch -  5000  Cost -  1711.5781753885194
# Epoch -  6000  Cost -  1617.432276403901
# Epoch -  7000  Cost -  1544.8651351173237
# Epoch -  8000  Cost -  1486.1477966046575
# Epoch -  9000  Cost -  1431.0386543982556
# Epoch -  10000  Cost -  1378.4113401482866
# Epoch -  11000  Cost -  1335.4631174927245
# Epoch -  12000  Cost -  1295.3729438110097
# Epoch -  13000  Cost -  1258.1308534879056
# Epoch -  14000  Cost -  1226.7665941055336
# Epoch -  15000  Cost -  1199.4753265351926
#
# Weights: [ 0.43220857  0.92724963  0.48784255  0.756117   -0.25451537  0.26520132
#   1.26390682  1.84479177 -0.01920602 -1.04120643  0.90754635 -0.36926508
#   0.66509204  0.67548657 -0.26463821 -0.70961993 -0.50149061 -0.50264851
#  -0.209653   -0.62104764  1.21302528  1.44360764  1.1115471   1.15621603
#   0.73734116  0.62176323  0.85954253  1.62443935  1.06422752  0.23808956
#  -4.23250363]

# %% [markdown]
# ## Testing

# %%
y_test_predicted = np.array([])
for i in range(X_test.shape[0]):
    yp = np.sign(np.dot(W, X_test.to_numpy()[i]))
    y_test_predicted = np.append(y_test_predicted, yp)

print("Accuracy: {}".format(round(accuracy_score(Y_test.to_numpy(), y_test_predicted), 2)))
print("Recall: {}".format(round(recall_score(Y_test.to_numpy(), y_test_predicted, average='micro'), 2)))
print("Precision: {}".format(round(precision_score(Y_test.to_numpy(), y_test_predicted, average='micro'), 2)))
# Out:
# Accuracy: 0.97
# Recall: 0.97
# Precision: 0.97
